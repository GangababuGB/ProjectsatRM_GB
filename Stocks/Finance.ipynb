# %%
import pandas as pd

# %%
df = pd.read_html("https://www.moneycontrol.com/markets/indian-indices/")

# %%
df
# Out:
# [      Stock Name                Sector      LTP  Change  %Chg
#  0          Wipro  Computers - Software   451.15  -30.10 -6.25
#  1       HCL Tech  Computers - Software  1009.40  -64.30 -5.99
#  2        Infosys  Computers - Software  1427.15  -82.05 -5.44
#  3  Tech Mahindra  Computers - Software  1108.35  -63.70 -5.43
#  4            TCS  Computers - Software  3261.95 -186.85 -5.42,
#           Stock Name                        Sector      LTP  Change  %Chg
#  0        Tata Steel                  Iron & Steel  1122.15  -58.10 -4.92
#  1         JSW Steel                 Steel - Large   600.20  -30.85 -4.89
#  2          Hindalco                  Iron & Steel   417.00  -19.10 -4.38
#  3   TATA Cons. Prod    Plantations - Tea & Coffee   721.30  -33.00 -4.37
#  4     IndusInd Bank        Banks - Private Sector   866.25  -36.90 -4.09
#  5       Tata Motors            Auto - LCVs & HCVs   398.65  -16.50 -3.97
#  6         HDFC Life       Life & Health Insurance   528.70  -21.30 -3.87
# ...

# %%
df2 = pd.read_html("https://www.moneycontrol.com/markets/indian-indices/top-nse-50-companies-list/9?classic=true&categoryId=1&exType=N")

# %%
df2
# Out:
# [      Stock Name                Sector      LTP  Change  %Chg
#  0          Wipro  Computers - Software   451.15  -30.10 -6.25
#  1       HCL Tech  Computers - Software  1009.40  -64.30 -5.99
#  2        Infosys  Computers - Software  1427.15  -82.05 -5.44
#  3  Tech Mahindra  Computers - Software  1108.35  -63.70 -5.43
#  4            TCS  Computers - Software  3261.95 -186.85 -5.42,
#           Stock Name                        Sector      LTP  Change  %Chg
#  0        Tata Steel                  Iron & Steel  1122.15  -58.10 -4.92
#  1         JSW Steel                 Steel - Large   600.20  -30.85 -4.89
#  2          Hindalco                  Iron & Steel   417.00  -19.10 -4.38
#  3   TATA Cons. Prod    Plantations - Tea & Coffee   721.30  -33.00 -4.37
#  4     IndusInd Bank        Banks - Private Sector   866.25  -36.90 -4.09
#  5       Tata Motors            Auto - LCVs & HCVs   398.65  -16.50 -3.97
#  6         HDFC Life       Life & Health Insurance   528.70  -21.30 -3.87
# ...

# %% [markdown]
# ## AutoVantage

# %%
key ='1E9DNFQ7WU3J4B7X'

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=demo'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'IBM', '3. Last Refreshed': '2022-05-19 20:00:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2022-05-19 20:00:00': {'1. open': '129.8700', '2. high': '129.8700', '3. low': '129.8700', '4. close': '129.8700', '5. volume': '150'}, '2022-05-19 19:40:00': {'1. open': '129.7500', '2. high': '129.7500', '3. low': '129.7500', '4. close': '129.7500', '5. volume': '475'}, '2022-05-19 19:30:00': {'1. open': '129.7100', '2. high': '129.7100', '3. low': '129.7100', '4. close': '129.7100', '5. volume': '200'}, '2022-05-19 19:05:00': {'1. open': '129.6600', '2. high': '129.6600', '3. low': '129.6600', '4. close': '129.6600', '5. volume': '100'}, '2022-05-19 19:00:00': {'1. open': '129.8700', '2. high': '129.8700', '3. low': '129.8700', '4. close': '129.8700', '5. volume': '200'}, '2022-05-19 18:05:00': {'1. open': '129.6000', '2.
# ...

# %%
import csv
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
CSV_URL = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol=IBM&interval=1min&apikey=1E9DNFQ7WU3J4B7X'

with requests.Session() as s:
    download = s.get(CSV_URL)
    decoded_content = download.content.decode('utf-8')
    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    my_list = list(cr)
    for row in my_list:
        print(row)
# Out:
# ['time', 'open', 'high', 'low', 'close', 'volume']
# ['2022-05-19 19:59:00', '129.87', '129.87', '129.87', '129.87', '150']
# ['2022-05-19 19:38:00', '129.75', '129.75', '129.75', '129.75', '475']
# ['2022-05-19 19:29:00', '129.71', '129.71', '129.71', '129.71', '100']
# ['2022-05-19 19:28:00', '129.71', '129.71', '129.71', '129.71', '100']
# ['2022-05-19 19:04:00', '129.66', '129.66', '129.66', '129.66', '100']
# ['2022-05-19 19:00:00', '129.87', '129.87', '129.87', '129.87', '200']
# ['2022-05-19 18:01:00', '129.6', '129.6', '129.6', '129.6', '100']
# ['2022-05-19 17:38:00', '129.66', '129.66', '129.58', '129.58', '805']
# ['2022-05-19 17:05:00', '129.66', '129.66', '129.66', '129.66', '100']
# ['2022-05-19 16:57:00', '129.65', '129.65', '129.65', '129.65', '302']
# ['2022-05-19 16:49:00', '129.66', '129.66', '129.66', '129.66', '1012']
# ['2022-05-19 16:43:00', '129.66', '129.66', '129.66', '129.66', '386']
# ['2022-05-19 16:42:00', '129.55', '129.55', '129.55', '129.55', '100']
# ...

# %%
import requests

url = "https://yh-finance.p.rapidapi.com/auto-complete"

# querystring = [{"q":"tesla","region":"US"}, {"q":"","region":"US"}]
querystring = {"q":"tesla","region":"US"}

headers = {
"X-RapidAPI-Host": "yh-finance.p.rapidapi.com",
"X-RapidAPI-Key": "3a02aa1ef6msh5cddb35615b11c5p10b76fjsnb2184ee525f7"
}

response = requests.request("GET", url, headers=headers, params=querystring)
data = response.json()

# %%
data
# Out:
# {'explains': [],
#  'count': 15,
#  'quotes': [{'exchange': 'NMS',
#    'shortname': 'Tesla, Inc.',
#    'quoteType': 'EQUITY',
#    'symbol': 'TSLA',
#    'index': 'quotes',
#    'score': 1711982.0,
#    'typeDisp': 'Equity',
#    'longname': 'Tesla, Inc.',
#    'exchDisp': 'NASDAQ',
#    'sector': 'Consumer Cyclical',
#    'industry': 'Auto Manufacturers',
#    'dispSecIndFlag': True,
#    'isYahooFinance': True},
#   {'exchange': 'NEO',
#    'shortname': 'TESLA, INC. CDR (CAD HEDGED)',
#    'quoteType': 'EQUITY',
#    'symbol': 'TSLA.NE',
#    'index': 'quotes',
#    'score': 23076.0,
#    'typeDisp': 'Equity',
#    'longname': 'Tesla, Inc.',
#    'exchDisp': 'NEO',
#    'sector': 'Consumer Cyclical',
#    'industry': 'Auto Manufacturers',
#    'isYahooFinance': True},
#   {'exchange': 'GER',
#    'shortname': 'TESLA INC',
#    'quoteType': 'EQUITY',
#    'symbol': 'TL0.DE',
#    'index': 'quotes',
#    'score': 20599.0,
#    'typeDisp': 'Equity',
#    'longname': 'Tesla, Inc.',
# ...

# %%
data.keys()
# Out:
# dict_keys(['explains', 'count', 'quotes', 'news', 'nav', 'lists', 'researchReports', 'screenerFieldResults', 'totalTime', 'timeTakenForQuotes', 'timeTakenForNews', 'timeTakenForAlgowatchlist', 'timeTakenForPredefinedScreener', 'timeTakenForCrunchbase', 'timeTakenForNav', 'timeTakenForResearchReports', 'timeTakenForScreenerField', 'timeTakenForCulturalAssets'])

# %%
data.values()
# Out:
# dict_values([[], 16, [{'exchange': 'NYQ', 'shortname': 'Regions Financial Corporation', 'quoteType': 'EQUITY', 'symbol': 'RF', 'index': 'quotes', 'score': 26580.0, 'typeDisp': 'Equity', 'longname': 'Regions Financial Corporation', 'exchDisp': 'NYSE', 'sector': 'Financial Services', 'industry': 'Banks—Regional', 'dispSecIndFlag': True, 'isYahooFinance': True}, {'exchange': 'PCX', 'shortname': 'Direxion Daily Regional Banks B', 'quoteType': 'ETF', 'symbol': 'DPST', 'index': 'quotes', 'score': 22621.0, 'typeDisp': 'ETF', 'longname': 'Direxion Daily Regional Banks Bull 3X Shares', 'exchDisp': 'NYSEArca', 'isYahooFinance': True}, {'exchange': 'PCX', 'shortname': 'SPDR S&P Regional Banking ETF', 'quoteType': 'ETF', 'symbol': 'KRE', 'index': 'quotes', 'score': 22255.0, 'typeDisp': 'ETF', 'longname': 'SPDR\xa0S&P\xa0Regional Banking ETF', 'exchDisp': 'NYSEArca', 'isYahooFinance': True}, {'exchange': 'ASE', 'shortname': 'Regional Health Properties, Inc', 'quoteType': 'EQUITY', 'symbol': 'RHE'
# ...

# %%
import csv
import requests
import pandas as pd

# %% [markdown]
# ### IBM (United States)

# %%
key = '1E9DNFQ7WU3J4B7X'

# %%
CSV_URL = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol=IBM&interval=1min&apikey='+key

with requests.Session() as s:
    download = s.get(CSV_URL)
    decoded_content = download.content.decode('utf-8')
    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    my_list = pd.DataFrame(cr)

# %%
my_list
# Out:
#                         0              1              2              3  \
# 0                    time           open           high            low
# 1     2022-05-19 19:59:00         129.87         129.87         129.87
# 2     2022-05-19 19:38:00         129.75         129.75         129.75
# 3     2022-05-19 19:29:00         129.71         129.71         129.71
# 4     2022-05-19 19:28:00         129.71         129.71         129.71
# ...                   ...            ...            ...            ...
# 9648  2022-04-20 04:53:00  129.421591594  129.421591594  129.421591594
# 9649  2022-04-20 04:51:00  129.293167757  129.382076567  129.293167757
# 9650  2022-04-20 04:15:00  129.391955324  129.391955324  129.391955324
# 9651  2022-04-20 04:04:00  129.520379161  129.520379161  129.520379161
# 9652  2022-04-20 04:03:00  129.589530458  129.589530458  129.589530458
#
#                   4       5
# 0             close  volume
# 1            129.87     150
# ...

# %% [markdown]
# ### IBM (United States) - Full

# %%
CSV_URL ='https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&outputsize=full&apikey='+key

# %%
r = requests.get(CSV_URL)
data = r.json()
data
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'IBM',
#   '3. Last Refreshed': '2022-05-19',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2022-05-19': {'1. open': '132.0000',
#    '2. high': '132.3200',
#    '3. low': '128.7100',
#    '4. close': '129.6600',
#    '5. volume': '5819664'},
#   '2022-05-18': {'1. open': '137.1000',
#    '2. high': '137.6150',
#    '3. low': '132.1700',
#    '4. close': '132.9400',
#    '5. volume': '6003015'},
#   '2022-05-17': {'1. open': '137.1900',
#    '2. high': '138.3700',
#    '3. low': '135.6400',
#    '4. close': '138.3700',
#    '5. volume': '4372909'},
#   '2022-05-16': {'1. open': '133.1000',
#    '2. high': '136.5100',
#    '3. low': '132.4100',
#    '4. close': '135.0300',
#    '5. volume': '4250395'},
#   '2022-05-13': {'1. open': '133.0000',
#    '2. high': '133.8000',
#    '3. low': '131.0500',
#    '4. close': '133.6000',
# ...

# %% [markdown]
# x = data
# for e in range(len(x)):
#     print(([x for x in x.keys()][e], [x for x in x.values()][e]))

# %%
rmd = data.pop('Meta Data')
rmd
# Out:
# {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#  '2. Symbol': 'IBM',
#  '3. Last Refreshed': '2022-05-19',
#  '4. Output Size': 'Full size',
#  '5. Time Zone': 'US/Eastern'}

# %%
data
# Out:
# {'Time Series (Daily)': {'2022-05-19': {'1. open': '132.0000',
#    '2. high': '132.3200',
#    '3. low': '128.7100',
#    '4. close': '129.6600',
#    '5. volume': '5819664'},
#   '2022-05-18': {'1. open': '137.1000',
#    '2. high': '137.6150',
#    '3. low': '132.1700',
#    '4. close': '132.9400',
#    '5. volume': '6003015'},
#   '2022-05-17': {'1. open': '137.1900',
#    '2. high': '138.3700',
#    '3. low': '135.6400',
#    '4. close': '138.3700',
#    '5. volume': '4372909'},
#   '2022-05-16': {'1. open': '133.1000',
#    '2. high': '136.5100',
#    '3. low': '132.4100',
#    '4. close': '135.0300',
#    '5. volume': '4250395'},
#   '2022-05-13': {'1. open': '133.0000',
#    '2. high': '133.8000',
#    '3. low': '131.0500',
#    '4. close': '133.6000',
#    '5. volume': '4195218'},
#   '2022-05-12': {'1. open': '131.2700',
#    '2. high': '133.6200',
#    '3. low': '130.4100',
#    '4. close': '132.9000',
#    '5. volume': '5384809'},
# ...

# %%
rmd = data.pop('Time Series (Daily)')
rmd
# Out:
# {'2022-05-19': {'1. open': '132.0000',
#   '2. high': '132.3200',
#   '3. low': '128.7100',
#   '4. close': '129.6600',
#   '5. volume': '5819664'},
#  '2022-05-18': {'1. open': '137.1000',
#   '2. high': '137.6150',
#   '3. low': '132.1700',
#   '4. close': '132.9400',
#   '5. volume': '6003015'},
#  '2022-05-17': {'1. open': '137.1900',
#   '2. high': '138.3700',
#   '3. low': '135.6400',
#   '4. close': '138.3700',
#   '5. volume': '4372909'},
#  '2022-05-16': {'1. open': '133.1000',
#   '2. high': '136.5100',
#   '3. low': '132.4100',
#   '4. close': '135.0300',
#   '5. volume': '4250395'},
#  '2022-05-13': {'1. open': '133.0000',
#   '2. high': '133.8000',
#   '3. low': '131.0500',
#   '4. close': '133.6000',
#   '5. volume': '4195218'},
#  '2022-05-12': {'1. open': '131.2700',
#   '2. high': '133.6200',
#   '3. low': '130.4100',
#   '4. close': '132.9000',
#   '5. volume': '5384809'},
#  '2022-05-11': {'1. open': '129.8600',
#   '2. high': '132.9600',
#   '3. low': '129.8600',
# ...

# %%
rmd.values()
# Out:
# dict_values([{'1. open': '132.0000', '2. high': '132.3200', '3. low': '128.7100', '4. close': '129.6600', '5. volume': '5819664'}, {'1. open': '137.1000', '2. high': '137.6150', '3. low': '132.1700', '4. close': '132.9400', '5. volume': '6003015'}, {'1. open': '137.1900', '2. high': '138.3700', '3. low': '135.6400', '4. close': '138.3700', '5. volume': '4372909'}, {'1. open': '133.1000', '2. high': '136.5100', '3. low': '132.4100', '4. close': '135.0300', '5. volume': '4250395'}, {'1. open': '133.0000', '2. high': '133.8000', '3. low': '131.0500', '4. close': '133.6000', '5. volume': '4195218'}, {'1. open': '131.2700', '2. high': '133.6200', '3. low': '130.4100', '4. close': '132.9000', '5. volume': '5384809'}, {'1. open': '129.8600', '2. high': '132.9600', '3. low': '129.8600', '4. close': '130.7500', '5. volume': '5301131'}, {'1. open': '135.0000', '2. high': '135.4100', '3. low': '128.4300', '4. close': '129.1300', '5. volume': '8642398'}, {'1. open': '134.4100', '2. high': '136.3
# ...

# %%
df = pd.DataFrame(rmd)
df.T
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 2022-05-19  132.0000  132.3200  128.7100  129.6600   5819664
# 2022-05-18  137.1000  137.6150  132.1700  132.9400   6003015
# 2022-05-17  137.1900  138.3700  135.6400  138.3700   4372909
# 2022-05-16  133.1000  136.5100  132.4100  135.0300   4250395
# 2022-05-13  133.0000  133.8000  131.0500  133.6000   4195218
# ...              ...       ...       ...       ...       ...
# 1999-11-05   92.7500   92.9400   90.1900   90.2500  13737600
# 1999-11-04   94.4400   94.4400   90.0000   91.5600  16697600
# 1999-11-03   95.8700   95.9400   93.5000   94.3700  10369100
# 1999-11-02   96.7500   96.8100   93.6900   94.8100  11105400
# 1999-11-01   98.5000   98.8100   96.3700   96.7500   9551800
#
# [5675 rows x 5 columns]

# %%
M_CSV_URL='https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=IBM&apikey='+key

with requests.Session() as s:
    download = s.get(M_CSV_URL)
    decoded_content = download.content.decode('utf-8')
    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    m_my_list = pd.DataFrame(cr)

# %% [markdown]
# ## RELIANCE.BSE

# %%
CSV_URL = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=RELIANCE.BSE&outputsize=full&apikey='+key
r = requests.get(CSV_URL)
data = r.json()
data
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'RELIANCE.BSE',
#   '3. Last Refreshed': '2022-05-19',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2022-05-19': {'1. open': '2470.0000',
#    '2. high': '2511.0000',
#    '3. low': '2466.4500',
#    '4. close': '2479.2000',
#    '5. volume': '728658'},
#   '2022-05-18': {'1. open': '2539.0000',
#    '2. high': '2570.0000',
#    '3. low': '2508.3000',
#    '4. close': '2538.8000',
#    '5. volume': '276653'},
#   '2022-05-17': {'1. open': '2443.0000',
#    '2. high': '2540.3999',
#    '3. low': '2435.0000',
#    '4. close': '2530.7000',
#    '5. volume': '336675'},
#   '2022-05-16': {'1. open': '2432.0000',
#    '2. high': '2480.7500',
#    '3. low': '2416.4500',
#    '4. close': '2427.3999',
#    '5. volume': '207222'},
#   '2022-05-13': {'1. open': '2432.0000',
#    '2. high': '2478.0000',
#    '3. low': '2416.0500',
# ...

# %%
#CSV_URL = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol=IBM&interval=1min&apikey='+key

# %%
CSV_URL = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=RELIANCE.BSE&outputsize=full&apikey='+key
r = requests.get(CSV_URL)
data = r.json()
data
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'RELIANCE.BSE',
#   '3. Last Refreshed': '2022-05-19',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2022-05-19': {'1. open': '2470.0000',
#    '2. high': '2511.0000',
#    '3. low': '2466.4500',
#    '4. close': '2479.2000',
#    '5. volume': '728658'},
#   '2022-05-18': {'1. open': '2539.0000',
#    '2. high': '2570.0000',
#    '3. low': '2508.3000',
#    '4. close': '2538.8000',
#    '5. volume': '276653'},
#   '2022-05-17': {'1. open': '2443.0000',
#    '2. high': '2540.3999',
#    '3. low': '2435.0000',
#    '4. close': '2530.7000',
#    '5. volume': '336675'},
#   '2022-05-16': {'1. open': '2432.0000',
#    '2. high': '2480.7500',
#    '3. low': '2416.4500',
#    '4. close': '2427.3999',
#    '5. volume': '207222'},
#   '2022-05-13': {'1. open': '2432.0000',
#    '2. high': '2478.0000',
#    '3. low': '2416.0500',
# ...

# %%
CSV_URL = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol=RELIANCE.BSE&interval=1min&apikey='+key
r = requests.get(CSV_URL)
# data = r.json()
# data
print(r)
# Out:
# <Response [200]>

# %%
key
# Out:
# '1E9DNFQ7WU3J4B7X'

# %%
# https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol=RELIANCE.BSE&interval=1min&apikey=1E9DNFQ7WU3J4B7X

# %%
CSV_URL = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=RELIANCE.BSE&outputsize=full&apikey='+key
r = requests.get(CSV_URL)
data = r.json()
data
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'RELIANCE.BSE',
#   '3. Last Refreshed': '2022-05-19',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2022-05-19': {'1. open': '2470.0000',
#    '2. high': '2511.0000',
#    '3. low': '2466.4500',
#    '4. close': '2479.2000',
#    '5. volume': '728658'},
#   '2022-05-18': {'1. open': '2539.0000',
#    '2. high': '2570.0000',
#    '3. low': '2508.3000',
#    '4. close': '2538.8000',
#    '5. volume': '276653'},
#   '2022-05-17': {'1. open': '2443.0000',
#    '2. high': '2540.3999',
#    '3. low': '2435.0000',
#    '4. close': '2530.7000',
#    '5. volume': '336675'},
#   '2022-05-16': {'1. open': '2432.0000',
#    '2. high': '2480.7500',
#    '3. low': '2416.4500',
#    '4. close': '2427.3999',
#    '5. volume': '207222'},
#   '2022-05-13': {'1. open': '2432.0000',
#    '2. high': '2478.0000',
#    '3. low': '2416.0500',
# ...

# %%
# url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=RELIANCE.BSE&interval=5min&apikey='+key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=RELIANCE.BSE&interval=5min&apikey='+key
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_INTRADAY.'}

# %%
from alpha_vantage.timeseries import TimeSeries

# %%
key = '1E9DNFQ7WU3J4B7X'
key
# Out:
# '1E9DNFQ7WU3J4B7X'

# %%
ts = TimeSeries(key=key, output_format='pandas')
data = ts.get_monthly_adjusted('AAPL')

# %%
# get_daily
# get_daily_adjusted
# get_intraday
# get_intraday_extended
# get_monthly
# get_monthly_adjusted
# get_quote_endpoint
# get_symbol_search
# get_weekly
# get_weekly adjusted

# %%
data
# Out:
# (            1. open  2. high  3. low  4. close  5. adjusted close  \
#  date
#  2022-05-19  156.710   166.48  136.60    137.35           137.3500
#  2022-04-29  174.030   178.49  155.38    157.65           157.4198
#  2022-03-31  164.695   179.61  150.10    174.61           174.3550
#  2022-02-28  174.010   176.65  152.00    165.12           164.8789
#  2022-01-31  177.830   182.94  154.70    174.78           174.3023
#  ...             ...      ...     ...       ...                ...
#  2000-04-28  135.500   139.50  104.87    124.06             0.9470
#  2000-03-31  118.560   150.38  114.00    135.81             1.0367
#  2000-02-29  104.000   119.94   97.00    114.62             0.8749
#  2000-01-31  104.870   121.50   86.50    103.75             0.7919
#  1999-12-31  101.000   118.00   91.06    102.81             0.7848
#
#                 6. volume  7. dividend amount
#  date
#  2022-05-19  1.663239e+09                0.23
#  2022-04-29  1.683548e+09                0.00
# ...

# %%
ts = TimeSeries(key=key, output_format='pandas')
data = ts.get_intraday('AAPL')

# %%
data
# Out:
# (                     1. open   2. high  3. low  4. close  5. volume
#  date
#  2022-05-20 20:00:00  137.580  137.6800  137.54   137.560    56086.0
#  2022-05-20 19:45:00  137.530  137.6000  137.53   137.570    34417.0
#  2022-05-20 19:30:00  137.390  137.5200  137.39   137.520    33791.0
#  2022-05-20 19:15:00  137.230  137.3900  137.20   137.390    19850.0
#  2022-05-20 19:00:00  137.250  137.3800  137.20   137.200    40869.0
#  ...                      ...       ...     ...       ...        ...
#  2022-05-19 12:15:00  139.445  139.8400  139.30   139.710  2728404.0
#  2022-05-19 12:00:00  140.060  140.4000  139.14   139.440  4597375.0
#  2022-05-19 11:45:00  138.420  140.1900  138.42   140.060  5159770.0
#  2022-05-19 11:30:00  138.280  138.8700  137.99   138.415  4808003.0
#  2022-05-19 11:15:00  138.730  139.2999  138.04   138.280  4205731.0
#
#  [100 rows x 5 columns],
#  {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#   '2. Symbol': 'AAPL',
# ...

# %%
data, meta_data = ts.get_intraday('GOOGL')

# %%
data
# Out:
#                       1. open  2. high     3. low  4. close  5. volume
# date
# 2022-05-20 19:30:00  2178.160  2178.16  2178.1600  2178.160      144.0
# 2022-05-20 18:30:00  2175.250  2175.25  2174.0000  2174.000      561.0
# 2022-05-20 17:45:00  2176.000  2176.00  2175.5000  2175.500     1428.0
# 2022-05-20 17:30:00  2175.000  2178.16  2175.0000  2178.160     1041.0
# 2022-05-20 17:15:00  2177.230  2179.79  2176.0100  2179.790     2990.0
# ...                       ...      ...        ...       ...        ...
# 2022-05-18 15:15:00  2248.270  2256.45  2248.2700  2253.115    32651.0
# 2022-05-18 15:00:00  2250.520  2257.00  2247.0000  2250.400    36569.0
# 2022-05-18 14:45:00  2257.485  2259.82  2248.8701  2250.310    39111.0
# 2022-05-18 14:30:00  2250.790  2259.28  2250.7000  2258.080    26953.0
# 2022-05-18 14:15:00  2251.830  2254.83  2247.7400  2250.100    29468.0
#
# [100 rows x 5 columns]

# %%
meta_data
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#  '2. Symbol': 'GOOGL',
#  '3. Last Refreshed': '2022-05-19 18:45:00',
#  '4. Interval': '15min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %%
data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')

# %%
meta_data
# Out:
# {'1. Information': 'Intraday (1min) open, high, low, close prices and volume',
#  '2. Symbol': 'MSFT',
#  '3. Last Refreshed': '2022-05-20 20:00:00',
#  '4. Interval': '1min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}

# %%
data
# Out:
#                       1. open   2. high    3. low  4. close  5. volume
# date
# 2022-05-20 20:00:00  252.8000  252.8000  252.8000  252.8000      366.0
# 2022-05-20 19:59:00  253.0000  253.0000  253.0000  253.0000      486.0
# 2022-05-20 19:50:00  252.8300  252.9000  252.8300  252.9000     1249.0
# 2022-05-20 19:44:00  252.7600  252.8100  252.7600  252.8100      362.0
# 2022-05-20 19:42:00  252.7600  252.7600  252.7600  252.7600      240.0
# ...                       ...       ...       ...       ...        ...
# 2022-05-09 04:07:00  269.8914  269.8914  269.8914  269.8914      402.0
# 2022-05-09 04:05:00  270.1408  270.1408  270.1408  270.1408     1454.0
# 2022-05-09 04:03:00  270.3503  270.3503  270.3503  270.3503      995.0
# 2022-05-09 04:02:00  270.4401  270.4401  270.4401  270.4401     2671.0
# 2022-05-09 04:01:00  271.1484  271.5374  271.1484  271.5374     1327.0
#
# [6748 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
data['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()

# %%
data.loc[:,'1. open':'4. close'].plot()
plt.show()

# %%
from alpha_vantage.techindicators import TechIndicators

# %%
ti = TechIndicators(key=key, output_format='pandas')
data, meta_data = ti.get_bbands(symbol='MSFT', interval='60min', time_period=60)
data.plot()
plt.title('BBbands indicator for  MSFT stock (60 min)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\GANGAB~1.M\AppData\Local\Temp/ipykernel_10044/1256060436.py in <module>
#       1 ti = TechIndicators(key=key, output_format='pandas')
# ----> 2 data, meta_data = ti.get_bbands(symbol='MSFT', interval='60min', time_period=60)
#       3 data.plot()
#       4 plt.title('BBbands indicator for  MSFT stock (60 min)')
#       5 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\alpha_vantage\alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     216         @wraps(func)
#     217         def _format_wrapper(self, *args, **kwargs):
# --> 218             call_response, data_key, meta_data_key = func(
#     219                 self, *args, **kwargs)
#     220             if 'json' in self.output_format.lower() or 'pandas' \
#
# ...

# %%
from alpha_vantage.sectorperformance import SectorPerformances
import matplotlib.pyplot as plt

sp = SectorPerformances(key=key, output_format='pandas')
data, meta_data = sp.get_sector()
data['Rank A: Real-Time Performance'].plot(kind='bar')
plt.title('Real Time Performance (%) per Sector')
plt.tight_layout()
plt.grid()
plt.show()

# %%
from alpha_vantage.cryptocurrencies import CryptoCurrencies
import matplotlib.pyplot as plt

cc = CryptoCurrencies(key=key, output_format='pandas')
data, meta_data = cc.get_digital_currency_daily(symbol='BTC', market='CNY')
data['4b. close (USD)'].plot()
plt.tight_layout()
plt.title('Daily close value for bitcoin (BTC)')
plt.grid()
plt.show()

# %%
from alpha_vantage.foreignexchange import ForeignExchange
from pprint import pprint
cc = ForeignExchange(key=key)
# There is no metadata in this call
data, _ = cc.get_currency_exchange_rate(from_currency='BTC',to_currency='USD')
pprint(data)
# Out:
# {'1. From_Currency Code': 'BTC',
#  '2. From_Currency Name': 'Bitcoin',
#  '3. To_Currency Code': 'USD',
#  '4. To_Currency Name': 'United States Dollar',
#  '5. Exchange Rate': '29993.77000000',
#  '6. Last Refreshed': '2022-05-20 07:08:07',
#  '7. Time Zone': 'UTC',
#  '8. Bid Price': '29993.77000000',
#  '9. Ask Price': '29993.78000000'}

# %%
import asyncio
from alpha_vantage.async_support.timeseries import TimeSeries

symbols = ['AAPL', 'GOOG', 'TSLA', 'MSFT']


async def get_data(symbol):
    ts = TimeSeries(key=key)
    data, _ = await ts.get_quote_endpoint(symbol)
    await ts.close()
    return data

loop = asyncio.get_event_loop()

tasks = [get_data(symbol) for symbol in symbols]
group1 = asyncio.gather(*tasks)
results = loop.run_until_complete(group1)
loop.close()
print(results)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# C:\Users\GANGAB~1.M\AppData\Local\Temp/ipykernel_10044/139013342.py in <module>
#      15 tasks = [get_data(symbol) for symbol in symbols]
#      16 group1 = asyncio.gather(*tasks)
# ---> 17 results = loop.run_until_complete(group1)
#      18 loop.close()
#      19 print(results)
#
# C:\ProgramData\Anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     616         """
#     617         self._check_closed()
# --> 618         self._check_running()
#     619
#     620         new_task = not futures.isfuture(future)
#
# C:\ProgramData\Anaconda3\lib\asyncio\base_events.py in _check_running(self)
#     576     def _check_running(self):
#     577         if self.is_running():
# --> 578             raise RuntimeError('This event loop is already running')
#     579         if events._get_running_loop() is not None:
# ...

# %%
# https://github.com/prediqtiv/alpha-vantage-cookbook/blob/master/symbol-lists.md
# https://en.wikipedia.org/wiki/Bombay_Stock_Exchange

# %%
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=NYSE:WIT&apikey=tbd1
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=BSE:507685&apikey=tbd1
# https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=BSE:507685&apikey=tbd1
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=BSE:500470&apikey=tbd1
# https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=BSE:507685&apikey=tbd1
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=BSE:500477&apikey=KEY&outputsize=full

# %%
# https://en.wikipedia.org/wiki/National_Stock_Exchange_of_India
# https://www.nseindia.com/

# %%
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=NSE:ASHOKLEY&apikey=tbd1&outputsize=full
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=NSE:HDFC&apikey=KEY&outputsize=full
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=NSE:SBIN&apikey=KEY&outputsize=full
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=NSE:LT&apikey=KEY&outputsize=full
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=NSE:ARVSMART&apikey=

# %%
# NIFTY 50 and Nifty 500
# https://en.wikipedia.org/wiki/NIFTY_50
# https://www.nseindia.com/live_market/dynaContent/live_watch/equities_stock_watch.htm?cat=N
# https://www.nseindia.com/content/indices/ind_nifty50list.csv
# https://www.nseindia.com/content/indices/ind_nifty500list.csv

# %%
import pandas as pd

# %%
CSV_URL = 'https://www.alphavantage.co/query?function=LISTING_STATUS&apikey=demo'

# %%
df = pd.read_csv(CSV_URL)
df
# Out:
#       symbol                                    name   exchange assetType  \
# 0          A                Agilent Technologies Inc       NYSE     Stock
# 1         AA                              Alcoa Corp       NYSE     Stock
# 2        AAA        AAF FIRST PRIORITY CLO BOND ETF   NYSE ARCA       ETF
# 3       AAAU         Goldman Sachs Physical Gold ETF       BATS       ETF
# 4        AAC  Ares Acquisition Corporation - Class A       NYSE     Stock
# ...      ...                                     ...        ...       ...
# 12604   ZYME                           Zymeworks Inc       NYSE     Stock
# 12605   ZYNE             Zynerba Pharmaceuticals Inc     NASDAQ     Stock
# 12606   ZYXI                               Zynex Inc     NASDAQ     Stock
# 12607    ZZK                                     NaN  NYSE ARCA     Stock
# 12608    ZZZ                     TEST TICKER FOR UTP  NYSE ARCA     Stock
#
#           ipoDate  delistingDate  status
# ...

# %%
# https://www.alphavantage.co/query?function=LISTING_STATUS&date=2014-07-10&state=delisted&apikey=demo

# %%
df.value_counts('exchange')
# Out:
# exchange
# NASDAQ       5793
# NYSE         4003
# NYSE ARCA    1916
# BATS          579
# NYSE MKT      315
# dtype: int64

# %%
CSV_URL = 'https://www.alphavantage.co/query?function=LISTING_STATUS&apikey='+key

# %%
df = pd.read_csv(CSV_URL)
df
# Out:
#       symbol                                    name   exchange assetType  \
# 0          A                Agilent Technologies Inc       NYSE     Stock
# 1         AA                              Alcoa Corp       NYSE     Stock
# 2        AAA        AAF FIRST PRIORITY CLO BOND ETF   NYSE ARCA       ETF
# 3       AAAU         Goldman Sachs Physical Gold ETF       BATS       ETF
# 4        AAC  Ares Acquisition Corporation - Class A       NYSE     Stock
# ...      ...                                     ...        ...       ...
# 12601   ZYME                           Zymeworks Inc       NYSE     Stock
# 12602   ZYNE             Zynerba Pharmaceuticals Inc     NASDAQ     Stock
# 12603   ZYXI                               Zynex Inc     NASDAQ     Stock
# 12604    ZZK                                     NaN  NYSE ARCA     Stock
# 12605    ZZZ                     TEST TICKER FOR UTP  NYSE ARCA     Stock
#
#           ipoDate  delistingDate  status
# ...

# %%
df['exchange'] = 'BATS'

# %%
df
# Out:
#       symbol                                    name exchange assetType  \
# 0          A                Agilent Technologies Inc     BATS     Stock
# 1         AA                              Alcoa Corp     BATS     Stock
# 2        AAA        AAF FIRST PRIORITY CLO BOND ETF      BATS       ETF
# 3       AAAU         Goldman Sachs Physical Gold ETF     BATS       ETF
# 4        AAC  Ares Acquisition Corporation - Class A     BATS     Stock
# ...      ...                                     ...      ...       ...
# 12604   ZYME                           Zymeworks Inc     BATS     Stock
# 12605   ZYNE             Zynerba Pharmaceuticals Inc     BATS     Stock
# 12606   ZYXI                               Zynex Inc     BATS     Stock
# 12607    ZZK                                     NaN     BATS     Stock
# 12608    ZZZ                     TEST TICKER FOR UTP     BATS     Stock
#
#           ipoDate  delistingDate  status
# 0      1999-11-18            NaN  Active
# ...

# %%
df.value_counts('exchange')
# Out:
# exchange
# NASDAQ       5793
# NYSE         4003
# NYSE ARCA    1916
# BATS          579
# NYSE MKT      315
# dtype: int64

# %%
{
    "tags": [
        "hide-output"
    ]
}
# Out:
# {'tags': ['hide-output']}

# %%
key
# Out:
# '1E9DNFQ7WU3J4B7X'

# %%
data, meta_data = ts.get_intraday('GOOGL', interval='1min')

# %%
meta_data
# Out:
# {'1. Information': 'Intraday (1min) open, high, low, close prices and volume',
#  '2. Symbol': 'GOOGL',
#  '3. Last Refreshed': '2022-05-19 18:34:00',
#  '4. Interval': '1min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %%
data
# Out:
#                        1. open    2. high     3. low  4. close  5. volume
# date
# 2022-05-19 18:34:00  2212.0100  2212.0100  2212.0100  2212.010      205.0
# 2022-05-19 18:15:00  2212.0100  2212.0100  2212.0100  2212.010      103.0
# 2022-05-19 17:38:00  2209.0100  2209.0100  2209.0100  2209.010      356.0
# 2022-05-19 17:30:00  2210.9900  2210.9900  2210.9900  2210.990      374.0
# 2022-05-19 17:10:00  2210.0000  2210.0000  2210.0000  2210.000      449.0
# ...                        ...        ...        ...       ...        ...
# 2022-05-19 14:39:00  2220.0000  2223.5300  2220.0000  2221.945     5513.0
# 2022-05-19 14:37:00  2211.6800  2214.3650  2211.3500  2214.365      960.0
# 2022-05-19 14:36:00  2212.9099  2212.9099  2210.6575  2211.900     1869.0
# 2022-05-19 14:35:00  2212.2550  2213.0600  2212.2550  2213.060     1762.0
# 2022-05-19 14:34:00  2211.1900  2212.3600  2211.1900  2212.360     1561.0
#
# [100 rows x 5 columns]

# %%
# NSE:HEROMOTOCO or BSE:HEROMOTOCO

# %%
ts = TimeSeries(key=key, output_format='pandas')

# %%
symbol = 'HEROMOTOCO:BSE'

# %%
data, meta_data = ts.get_intraday(symbol, interval='1min')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\GANGAB~1.M\AppData\Local\Temp/ipykernel_2200/1438302643.py in <module>
# ----> 1 data, meta_data = ts.get_intraday(symbol, interval='1min')
#
# C:\ProgramData\Anaconda3\lib\site-packages\alpha_vantage\alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     216         @wraps(func)
#     217         def _format_wrapper(self, *args, **kwargs):
# --> 218             call_response, data_key, meta_data_key = func(
#     219                 self, *args, **kwargs)
#     220             if 'json' in self.output_format.lower() or 'pandas' \
#
# C:\ProgramData\Anaconda3\lib\site-packages\alpha_vantage\alphavantage.py in _call_wrapper(self, *args, **kwargs)
#     158             else:
#     159                 url = '{}{}'.format(url, apikey_parameter)
# ...

# %%
https://github.com/prediqtiv/alpha-vantage-cookbook/blob/master/symbol-lists.md

# %%
url = 'https://g.co/finance/NIFTY_50:INDEXNSE'

# %%
import csv

# %%
import requests
r = requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
# https://github.com/faizanahemad/data-science-utils/tree/master/data_science_utils/financial

# %%
from bs4 import BeautifulSoup
import requests, lxml, json
from itertools import zip_longest


def scrape_google_finance(ticker: str):
    # https://docs.python-requests.org/en/master/user/quickstart/#passing-parameters-in-urls
    params = {
        "hl": "en" # language
        }

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.60 Safari/537.36",
        }

    html = requests.get(f"https://www.google.com/finance/quote/{ticker}", params=params, headers=headers, timeout=30)
    soup = BeautifulSoup(html.text, "lxml")
    
    ticker_data = {"right_panel_data": {},
                    "ticker_info": {}}
    
    ticker_data["ticker_info"]["title"] = soup.select_one(".zzDege").text
    ticker_data["ticker_info"]["current_price"] = soup.select_one(".AHmHk .fxKbKc").text
    
    right_panel_keys = soup.select(".gyFHrc .mfs7Fc")
    right_panel_values = soup.select(".gyFHrc .P6K39c")
    
    for key, value in zip_longest(right_panel_keys, right_panel_values):
        key_value = key.text.lower().replace(" ", "_")

        ticker_data["right_panel_data"][key_value] = value.text
    
    return ticker_data

# %%
data = scrape_google_finance(ticker="NIFTY_50:INDEXNSE")
print(json.dumps(data, indent=2))
# Out:
# {
#   "right_panel_data": {
#     "previous_close": "16,266.15",
#     "day_range": "16,185.75 - 16,414.70",
#     "year_range": "15,374.00 - 18,604.45"
#   },
#   "ticker_info": {
#     "title": "NIFTY 50",
#     "current_price": "16,191.65"
#   }
# }

# %%
print(json.dumps(data['ticker_info'], indent=2))
# Out:
# "16,191.65"

# %%
symbol = 'HDFCBANK:NSE'

# %%
import schedule
import time

# %%
def gf_sec_scrape():
    data = scrape_google_finance(ticker=symbol)
    print(data)

# %%
schedule.every().seconds.do(gf_sec_scrape)
while True:
    schedule.run_pending()
# Out:
# {'right_panel_data': {'previous_close': '₹1,320.95', 'day_range': '₹1,299.10 - ₹1,329.95', 'year_range': '₹1,278.30 - ₹1,725.00', 'market_cap': '7.22T INR', 'p/e_ratio': '19.05', 'dividend_yield': '1.19%', 'primary_exchange': 'NSE', 'ceo': 'Sashidhar Jagdishan', 'founded': 'Aug 1994', 'headquarters': 'Mumbai, MaharashtraIndia', 'website': 'hdfcbank.com', 'employees': '141,579'}, 'ticker_info': {'title': 'HDFC Bank Limited', 'current_price': '₹1,301.30'}}
# {'right_panel_data': {'previous_close': '₹1,320.95', 'day_range': '₹1,299.10 - ₹1,329.95', 'year_range': '₹1,278.30 - ₹1,725.00', 'market_cap': '7.22T INR', 'p/e_ratio': '19.05', 'dividend_yield': '1.19%', 'primary_exchange': 'NSE', 'ceo': 'Sashidhar Jagdishan', 'founded': 'Aug 1994', 'headquarters': 'Mumbai, MaharashtraIndia', 'website': 'hdfcbank.com', 'employees': '141,579'}, 'ticker_info': {'title': 'HDFC Bank Limited', 'current_price': '₹1,301.30'}}
# ...

# %%
symbol = 'M&M:NSE'

# %%
def gf_sec_scrape():
    data = scrape_google_finance(ticker=symbol)
    print(data)

# %%
schedule.every().seconds.do(gf_sec_scrape)
while True:
    schedule.run_pending()
# Out:
# {'right_panel_data': {'previous_close': '₹903.80', 'day_range': '₹910.25 - ₹943.45', 'year_range': '₹671.15 - ₹979.00', 'market_cap': '1.12T INR', 'p/e_ratio': '19.42', 'dividend_yield': '0.93%', 'primary_exchange': 'NSE', 'ceo': 'Anish Shah', 'founded': 'Oct 2, 1945', 'headquarters': 'Mumbai, MaharashtraIndia', 'website': 'mahindra.com', 'employees': '260,000'}, 'ticker_info': {'title': 'Mahindra & Mahindra Limited', 'current_price': '₹941.00'}}
# {'right_panel_data': {'previous_close': '₹903.80', 'day_range': '₹910.25 - ₹943.45', 'year_range': '₹671.15 - ₹979.00', 'market_cap': '1.12T INR', 'p/e_ratio': '19.42', 'dividend_yield': '0.93%', 'primary_exchange': 'NSE', 'ceo': 'Anish Shah', 'founded': 'Oct 2, 1945', 'headquarters': 'Mumbai, MaharashtraIndia', 'website': 'mahindra.com', 'employees': '260,000'}, 'ticker_info': {'title': 'Mahindra & Mahindra Limited', 'current_price': '₹941.00'}}
# ...

# %%
symbol = '540719:BOM' # BSE

# %%
def gf_sec_scrape():
    data = scrape_google_finance(ticker=symbol)
    print(data)

# %%
schedule.every().seconds.do(gf_sec_scrape)
while True:
    schedule.run_pending()
# Out:
# {'right_panel_data': {'previous_close': '₹1,071.60', 'day_range': '₹1,051.10 - ₹1,091.70', 'year_range': '₹956.85 - ₹1,293.00', 'market_cap': '1.07T INR', 'p/e_ratio': '71.20', 'dividend_yield': '0.23%', 'primary_exchange': 'NSE', 'ceo': 'Mahesh Kumar Sharma', 'founded': 'Mar 2001', 'headquarters': 'Mumbai, MaharashtraIndia', 'website': 'sbilife.co.in', 'employees': '18,515'}, 'ticker_info': {'title': 'Sbi Life Insurance Company Ltd', 'current_price': '₹1,070.85'}}
# {'right_panel_data': {'previous_close': '₹1,071.60', 'day_range': '₹1,051.10 - ₹1,091.70', 'year_range': '₹956.85 - ₹1,293.00', 'market_cap': '1.07T INR', 'p/e_ratio': '71.20', 'dividend_yield': '0.23%', 'primary_exchange': 'NSE', 'ceo': 'Mahesh Kumar Sharma', 'founded': 'Mar 2001', 'headquarters': 'Mumbai, MaharashtraIndia', 'website': 'sbilife.co.in', 'employees': '18,515'}, 'ticker_info': {'title': 'Sbi Life Insurance Company Ltd', 'current_price': '₹1,070.85'}}
# ...

# %%
# https://en.wikipedia.org/wiki/List_of_companies_listed_on_the_National_Stock_Exchange_of_India
